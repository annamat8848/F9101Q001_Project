# %% [markdown]
# # Project 2020
#
# You have to work on the University dataset. It contains three different university rankings:
#
# The Times Higher Education World University Ranking, shortly Times,
#
# the Academic Ranking of World Universities, shortly Shanghai,
#
# the Center for World University Rankings, shortly cwur.

# %%
# importing necessary packeges
import pandas as pd
import numpy as np
import re

# %%
# impoprt shanghai dataset

url = 'https://drive.google.com/file/d/1rhjxG5mP_GlvAlLDdmWnrzDzfnSgAdcf/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
shanghai = pd.read_csv(path)

# %%
shanghai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
# impoprt times dataset

url = 'https://drive.google.com/file/d/1bxVqGhJaNaP9s3ETJsFw4HR7Y7u_Lujc/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
times = pd.read_csv(path)

# %%
times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
# 3       15,596                  7.8                    22%           42 : 58
# 4        7,929                  8.4                    27%           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
# impoprt cwur dataset

url = 'https://drive.google.com/file/d/1KMbNlxJDdSQhT0LeBC0vGMOXUv0jTZGI/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
cwur = pd.read_csv(path)

# %%
cwur.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
# Importing school country dataset

url = 'https://drive.google.com/file/d/1ULJv7TAQsCDH6YmCdNPYocDVqga5z90j/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
schools_countries =  pd.read_csv(path)

# %%
schools_countries.head()
# Out:
#                              school_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %%
schools_countries.rename(columns = {'school_name':'university_name'},inplace=True)
schools_countries.head()
# Out:
#                          university_name                   country
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America

# %% [markdown]
# ### Preprocessing

# %%
# Removing Nan
shanghai.dropna(subset=['university_name'], inplace=True)
times.dropna(subset=['university_name'], inplace=True)
cwur.dropna(subset=['institution'], inplace=True)

# %%
# Country names normalization

times['country'].replace('Unted Kingdom','United Kingdom', inplace=True)
times['country'].replace('Unisted States of America','United States of America', inplace=True)

# %%
# University names normalization

shanghai['UNI_ID']=shanghai['university_name'].replace({' of ':'','-': '', ',': '',' ':''}, regex = True).str.lower()
cwur['UNI_ID']=cwur['institution'].replace({' of ':'','-': '', ',': '',' ':''}, regex = True).str.lower()
times['UNI_ID']=times['university_name'].replace({' of ':'','-': '', ',': '',' ':''}, regex = True).str.lower()
schools_countries['UNI_ID']=schools_countries['university_name'].replace({' of ':'','-': '', ',': '',' ':''}, regex = True).str.lower()

# %%
len(shanghai['university_name'].unique())
# Out:
# 658

# %%
len(shanghai['UNI_ID'].unique())
# Out:
# 650

# %% [markdown]
# ### 1.For each university, extract from the times dataset the most recent and the least recent data, obtaining two separate dataframes

# %%
print(times.dtypes)
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international              object
# research                  float64
# citations                 float64
# income                     object
# total_score                object
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# UNI_ID                     object
# dtype: object

# %%
# Least recent

times_old = times.loc[times.groupby('UNI_ID')['year'].idxmin()]

# %%
# Most recent

times_recent = times.loc[times.groupby('UNI_ID')['year'].idxmax()]
times_recent.head()
# Out:
#      world_rank             university_name         country  teaching  \
# 2003    201-250          Aalborg University         Denmark      25.1
# 2056    251-300            Aalto University         Finland      31.1
# 1908       =106           Aarhus University         Denmark      36.9
# 2105    301-350      Aberystwyth University  United Kingdom      21.6
# 2404    601-800  Adam Mickiewicz University          Poland      20.0
#
#      international  research  citations income total_score num_students  \
# 2003          71.0      28.4       73.8   43.7           -       17,422
# 2056          65.4      32.8       62.1   61.6           -       16,099
# 1908          76.8      50.7       79.8   68.3        57.7       23,895
# 2105          72.2      18.9       67.2   31.3           -        9,252
# 2404          25.7      11.0       15.3   28.7           -       40,633
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 2003                 15.9                    15%           48 : 52  2016
# 2056                 24.2                    17%           32 : 68  2016
# 1908                 13.6                    14%           54 : 46  2016
# 2105                 19.2                    18%           48 : 52  2016
# 2404                 15.6                     1%           71 : 29  2016
#
#                         UNI_ID
# 2003         aalborguniversity
# 2056           aaltouniversity
# 1908          aarhusuniversity
# 2105     aberystwythuniversity
# 2404  adammickiewiczuniversity

# %% [markdown]
# ### 2.For each university, compute the improvement in income between the least recent and the most recent data points

# %%
old = times_old[['university_name','income','year','UNI_ID']]
recent = times_recent[['university_name','income','year','UNI_ID']]

# %%
new_old=pd.merge(old, recent, on='UNI_ID',suffixes=('_1', '_2'))

# %%
# Delete universities that appear only once

new_old = new_old[new_old['year_1']!=new_old['year_2']]
new_old.head()
# Out:
#         university_name_1 income_1  year_1                 UNI_ID  \
# 0      Aalborg University     36.4    2012      aalborguniversity
# 1        Aalto University     61.9    2012        aaltouniversity
# 2       Aarhus University     61.5    2011       aarhusuniversity
# 3  Aberystwyth University     35.5    2012  aberystwythuniversity
# 8   Alexandria University     36.0    2011   alexandriauniversity
#
#         university_name_2 income_2  year_2
# 0      Aalborg University     43.7    2016
# 1        Aalto University     61.6    2016
# 2       Aarhus University     68.3    2016
# 3  Aberystwyth University     31.3    2016
# 8   Alexandria University     29.7    2016

# %%
print(new_old.dtypes)
# Out:
# university_name_1    object
# income_1             object
# year_1                int64
# UNI_ID               object
# university_name_2    object
# income_2             object
# year_2                int64
# dtype: object

# %%
# Le variabili income sono 'object' per calcolare l'incremento devono essere convertite in variabili numeriche

new_old['income_1']=pd.to_numeric(new_old['income_1'],errors='coerce')
new_old['income_2']=pd.to_numeric(new_old['income_2'],errors='coerce')

# If 'coerce', then invalid parsing will be set as NaN

print(new_old.dtypes)
# Out:
# university_name_1     object
# income_1             float64
# year_1                 int64
# UNI_ID                object
# university_name_2     object
# income_2             float64
# year_2                 int64
# dtype: object

# %%
new_old['improvement ratio'] = new_old['income_2']/new_old['income_1']
new_old['improvement percent'] = 100*(new_old['improvement ratio']-1)

# %%
new_old['improvement diff'] = new_old['income_2']-new_old['income_1']
new_old.head()
# Out:
#         university_name_1  income_1  year_1                 UNI_ID  \
# 0      Aalborg University      36.4    2012      aalborguniversity
# 1        Aalto University      61.9    2012        aaltouniversity
# 2       Aarhus University      61.5    2011       aarhusuniversity
# 3  Aberystwyth University      35.5    2012  aberystwythuniversity
# 8   Alexandria University      36.0    2011   alexandriauniversity
#
#         university_name_2  income_2  year_2  improvement ratio  \
# 0      Aalborg University      43.7    2016           1.200549
# 1        Aalto University      61.6    2016           0.995153
# 2       Aarhus University      68.3    2016           1.110569
# 3  Aberystwyth University      31.3    2016           0.881690
# 8   Alexandria University      29.7    2016           0.825000
#
#    improvement percent  improvement diff
# 0            20.054945               7.3
# 1            -0.484653              -0.3
# 2            11.056911               6.8
# 3           -11.830986              -4.2
# 8           -17.500000              -6.3

# %% [markdown]
# ### 3.Find the university with the largest increase computed in the previous point

# %%
new_old.sort_values('improvement diff',ascending=False).head()
# Out:
#                      university_name_1  income_1  year_1  \
# 465                         TU Dresden      31.9    2012
# 278   Nanyang Technological University      40.0    2011
# 241                         LMU Munich      40.4    2011
# 203  Karlsruhe Institute of Technology      40.0    2011
# 276                  Nagoya University      33.1    2012
#
#                              UNI_ID                  university_name_2  \
# 465                       tudresden                         TU Dresden
# 278  nanyangtechnologicaluniversity   Nanyang Technological University
# 241                       lmumunich                         LMU Munich
# 203    karlsruheinstitutetechnology  Karlsruhe Institute of Technology
# 276                nagoyauniversity                  Nagoya University
#
#      income_2  year_2  improvement ratio  improvement percent  \
# 465      99.7    2016           3.125392           212.539185
# 278      99.9    2016           2.497500           149.750000
# 241     100.0    2016           2.475248           147.524752
# 203      99.5    2016           2.487500           148.750000
# 276      91.4    2016           2.761329           176.132931
#
#      improvement diff
# 465              67.8
# 278              59.9
# 241              59.6
# 203              59.5
# 276              58.3

# %%
new_old.loc[new_old['improvement percent'].idxmax()]
# Out:
# university_name_1      TU Dresden
# income_1                     31.9
# year_1                       2012
# UNI_ID                  tudresden
# university_name_2      TU Dresden
# income_2                     99.7
# year_2                       2016
# improvement ratio         3.12539
# improvement percent       212.539
# improvement diff             67.8
# Name: 465, dtype: object

# %% [markdown]
# ### 4.For each ranking, consider only the most recent data point. For each university, compute the maximum difference between the rankings (e.g. for Aarhus University the value is 122-73=49). Notice that some rankings are expressed as a range

# %%
shanghai_recent = shanghai.loc[shanghai.groupby('UNI_ID')['year'].idxmax()]
shanghai_recent.head()
# Out:
#      world_rank                       university_name national_rank  \
# 4697    301-400                    Aalborg University             5
# 4797    401-500                      Aalto University           4-6
# 4469         73                     Aarhus University             2
# 4497    101-150              Aix Marseille University           5-6
# 4798    401-500  Aristotle University of Thessaloniki             2
#
#       total_score  alumni  award  hici    ns   pub   pcp  year  \
# 4697          NaN     0.0    0.0  11.2   4.6  30.4  16.8  2015
# 4797          NaN     0.0    0.0   0.0  10.4  33.4  17.0  2015
# 4469         27.3    11.5   22.1  12.3  25.8  51.8  31.0  2015
# 4497          NaN    13.6    0.0  15.2  20.3  50.1  27.6  2015
# 4798          NaN     0.0    0.0   4.9   1.5  34.0  16.8  2015
#
#                                UNI_ID
# 4697                aalborguniversity
# 4797                  aaltouniversity
# 4469                 aarhusuniversity
# 4497           aixmarseilleuniversity
# 4798  aristotleuniversitythessaloniki

# %%
cwur_recent = cwur.loc[cwur.groupby('UNI_ID')['year'].idxmax()]
cwur_recent.head()
# Out:
#       world_rank                           institution         country  \
# 1764         565                    Aalborg University         Denmark
# 1620         421                      Aalto University         Finland
# 1321         122                     Aarhus University         Denmark
# 2013         814                Aberystwyth University  United Kingdom
# 2089         890  Adam Mickiewicz University in Poznań          Poland
#
#       national_rank  quality_of_education  alumni_employment  \
# 1764              5                   367                439
# 1620              4                   367                224
# 1321              2                   310                165
# 2013             59                   367                567
# 2089              5                   150                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1764                 218           596        660        287         520.0
# 1620                 218           336        403        645         424.0
# 1321                 106            91         81        101          95.0
# 2013                 218           842        552        511         754.0
# 2089                 218           675        775        812         932.0
#
#       patents  score  year                            UNI_ID
# 1764      401  44.59  2015                 aalborguniversity
# 1620      246  45.10  2015                   aaltouniversity
# 1321      154  49.65  2015                  aarhusuniversity
# 2013      607  44.22  2015             aberystwythuniversity
# 2089      657  44.14  2015  adammickiewiczuniversityinpoznań

# %%
times_recent_slim=times_recent[['year','world_rank','UNI_ID']]
shanghai_recent_slim=shanghai_recent[['year','world_rank','UNI_ID']]
cwur_recent_slim=cwur_recent[['year','world_rank','UNI_ID']]

# %%
# Unione dei tre dataset

shanghai_recent_slim.rename(columns = {'world_rank':'world_rank_shanghai','year':'year_shanghai'},inplace=True)

merged=pd.merge(pd.merge(cwur_recent_slim,times_recent_slim,on='UNI_ID',suffixes=('_cwur', '_times'),how='outer'),
                shanghai_recent_slim,
                on='UNI_ID',how='outer')

merged.head()
# Out:
#    year_cwur  world_rank_cwur                            UNI_ID  year_times  \
# 0     2015.0            565.0                 aalborguniversity      2016.0
# 1     2015.0            421.0                   aaltouniversity      2016.0
# 2     2015.0            122.0                  aarhusuniversity      2016.0
# 3     2015.0            814.0             aberystwythuniversity      2016.0
# 4     2015.0            890.0  adammickiewiczuniversityinpoznań         NaN
#
#   world_rank_times  year_shanghai world_rank_shanghai
# 0          201-250         2015.0             301-400
# 1          251-300         2015.0             401-500
# 2             =106         2015.0                  73
# 3          301-350            NaN                 NaN
# 4              NaN            NaN                 NaN

# %%
print(merged.dtypes)
# Out:
# year_cwur              float64
# world_rank_cwur        float64
# UNI_ID                  object
# year_times             float64
# world_rank_times        object
# year_shanghai          float64
# world_rank_shanghai     object
# dtype: object

# %%
# Funzione che restituisce la posizione media di un'università quando il suo ranking è espresso come intervallo
# Da applicare a world_rank_shanghai e world_rank_times 

def get_mean_range(element):
    
    if isinstance(element, str) :
    
        element = element.strip('=')
        element = element.split('-')

        if len(element) == 2:
            return (int(element[0])+int(element[1]))/2
        else:
            return int(element[0])     
    
    else:
        return element

# %%
prova = '201-250'
get_mean_range(prova)
# Out:
# 225.5

# %%
merged['world_rank_shanghai_num']=merged['world_rank_shanghai'].apply(get_mean_range)

# %%
merged['world_rank_times_num']=merged['world_rank_times'].apply(get_mean_range)

# %%
merged.head()
# Out:
#    year_cwur  world_rank_cwur                            UNI_ID  year_times  \
# 0     2015.0            565.0                 aalborguniversity      2016.0
# 1     2015.0            421.0                   aaltouniversity      2016.0
# 2     2015.0            122.0                  aarhusuniversity      2016.0
# 3     2015.0            814.0             aberystwythuniversity      2016.0
# 4     2015.0            890.0  adammickiewiczuniversityinpoznań         NaN
#
#   world_rank_times  year_shanghai world_rank_shanghai  \
# 0          201-250         2015.0             301-400
# 1          251-300         2015.0             401-500
# 2             =106         2015.0                  73
# 3          301-350            NaN                 NaN
# 4              NaN            NaN                 NaN
#
#    world_rank_shanghai_num  world_rank_times_num
# 0                    350.5                 225.5
# 1                    450.5                 275.5
# 2                     73.0                 106.0
# 3                      NaN                 325.5
# 4                      NaN                   NaN

# %%
# Restituisce la differenza maggiore tra i ranking di un'università

def max_rank_dif(row):
    return( max(row['world_rank_cwur'],row['world_rank_shanghai_num'],row['world_rank_times_num']) 
        - min(row['world_rank_cwur'],row['world_rank_shanghai_num'],row['world_rank_times_num']))

# %%
merged['max_rank_dif']=merged.apply(max_rank_dif,axis=1)

# Delete Nan
merged = merged.dropna(subset=["max_rank_dif"])
merged.head()
# Out:
#    year_cwur  world_rank_cwur                            UNI_ID  year_times  \
# 0     2015.0            565.0                 aalborguniversity      2016.0
# 1     2015.0            421.0                   aaltouniversity      2016.0
# 2     2015.0            122.0                  aarhusuniversity      2016.0
# 3     2015.0            814.0             aberystwythuniversity      2016.0
# 4     2015.0            890.0  adammickiewiczuniversityinpoznań         NaN
#
#   world_rank_times  year_shanghai world_rank_shanghai  \
# 0          201-250         2015.0             301-400
# 1          251-300         2015.0             401-500
# 2             =106         2015.0                  73
# 3          301-350            NaN                 NaN
# 4              NaN            NaN                 NaN
#
#    world_rank_shanghai_num  world_rank_times_num  max_rank_dif
# 0                    350.5                 225.5         339.5
# 1                    450.5                 275.5         175.0
# 2                     73.0                 106.0          49.0
# 3                      NaN                 325.5         488.5
# 4                      NaN                   NaN           0.0

# %%
# Referencing to school_countries to get standard names

uni_names=pd.merge(merged,schools_countries,on='UNI_ID')
uni_names[['university_name','max_rank_dif']].head()
# Out:
#                             university_name  max_rank_dif
# 0                        Aalborg University         339.5
# 1                          Aalto University         175.0
# 2                         Aarhus University          49.0
# 3                    Aberystwyth University         488.5
# 4  AGH University of Science and Technology          81.5

# %% [markdown]
# ### 5.Consider only the most recent data point of the times dataset. Compute the number of male and female students for each country.

# %%
print(times_recent.dtypes)
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international              object
# research                  float64
# citations                 float64
# income                     object
# total_score                object
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# UNI_ID                     object
# dtype: object

# %%
# Need a numeric variable
# Alcune migliaia specificate con la virgola

times_recent['num_students'].replace(',','', inplace=True,regex=True)
times_recent['num_students']=pd.to_numeric(times_recent['num_students'])
print(times_recent.dtypes)
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international              object
# research                  float64
# citations                 float64
# income                     object
# total_score                object
# num_students              float64
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# UNI_ID                     object
# dtype: object

# %%
times_recent['female_male_ratio'].replace(r'-',np.nan, inplace=True)
times_recent.head()
# Out:
#      world_rank             university_name         country  teaching  \
# 2003    201-250          Aalborg University         Denmark      25.1
# 2056    251-300            Aalto University         Finland      31.1
# 1908       =106           Aarhus University         Denmark      36.9
# 2105    301-350      Aberystwyth University  United Kingdom      21.6
# 2404    601-800  Adam Mickiewicz University          Poland      20.0
#
#      international  research  citations income total_score  num_students  \
# 2003          71.0      28.4       73.8   43.7           -       17422.0
# 2056          65.4      32.8       62.1   61.6           -       16099.0
# 1908          76.8      50.7       79.8   68.3        57.7       23895.0
# 2105          72.2      18.9       67.2   31.3           -        9252.0
# 2404          25.7      11.0       15.3   28.7           -       40633.0
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 2003                 15.9                    15%           48 : 52  2016
# 2056                 24.2                    17%           32 : 68  2016
# 1908                 13.6                    14%           54 : 46  2016
# 2105                 19.2                    18%           48 : 52  2016
# 2404                 15.6                     1%           71 : 29  2016
#
#                         UNI_ID
# 2003         aalborguniversity
# 2056           aaltouniversity
# 1908          aarhusuniversity
# 2105     aberystwythuniversity
# 2404  adammickiewiczuniversity

# %%
# Espressione regolare che inidentifica due gruppi: percentuale femmine e maschi

ratio = re.compile('^(?P<fem>\d+) : (?P<male>\d+)$')

prova = ratio.search('48 : 52')
prova.group('fem')
# Out:
# '48'

# %%
# Funzione che applica l'espressione regolare "ratio"

def get_genders_percent(element, gender):
    
    if isinstance(element, str) :
    
        found = ratio.search(element)

        if found:
            if gender == 'F':
                return int(found.group('fem'))/100

            if gender == 'M':
                return int(found.group('male'))/100
    
    else:
        return np.nan

# %%
# Proporzione
times_recent['females_p'] = times_recent['female_male_ratio'].apply(get_genders_percent, args=('F'))
times_recent['males_p'] = times_recent['female_male_ratio'].apply(get_genders_percent, args=('M'))
times_recent.head()
# Out:
#      world_rank             university_name         country  teaching  \
# 2003    201-250          Aalborg University         Denmark      25.1
# 2056    251-300            Aalto University         Finland      31.1
# 1908       =106           Aarhus University         Denmark      36.9
# 2105    301-350      Aberystwyth University  United Kingdom      21.6
# 2404    601-800  Adam Mickiewicz University          Poland      20.0
#
#      international  research  citations income total_score  num_students  \
# 2003          71.0      28.4       73.8   43.7           -       17422.0
# 2056          65.4      32.8       62.1   61.6           -       16099.0
# 1908          76.8      50.7       79.8   68.3        57.7       23895.0
# 2105          72.2      18.9       67.2   31.3           -        9252.0
# 2404          25.7      11.0       15.3   28.7           -       40633.0
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 2003                 15.9                    15%           48 : 52  2016
# 2056                 24.2                    17%           32 : 68  2016
# 1908                 13.6                    14%           54 : 46  2016
# 2105                 19.2                    18%           48 : 52  2016
# 2404                 15.6                     1%           71 : 29  2016
#
#                         UNI_ID  females_p  males_p
# 2003         aalborguniversity       0.48     0.52
# 2056           aaltouniversity       0.32     0.68
# 1908          aarhusuniversity       0.54     0.46
# 2105     aberystwythuniversity       0.48     0.52
# 2404  adammickiewiczuniversity       0.71     0.29

# %%
times_recent['females_num'] = round(times_recent['females_p']*times_recent['num_students'])
times_recent['males_num'] = round(times_recent['males_p']*times_recent['num_students'])
times_recent.head()
# Out:
#      world_rank             university_name         country  teaching  \
# 2003    201-250          Aalborg University         Denmark      25.1
# 2056    251-300            Aalto University         Finland      31.1
# 1908       =106           Aarhus University         Denmark      36.9
# 2105    301-350      Aberystwyth University  United Kingdom      21.6
# 2404    601-800  Adam Mickiewicz University          Poland      20.0
#
#      international  research  citations income total_score  num_students  \
# 2003          71.0      28.4       73.8   43.7           -       17422.0
# 2056          65.4      32.8       62.1   61.6           -       16099.0
# 1908          76.8      50.7       79.8   68.3        57.7       23895.0
# 2105          72.2      18.9       67.2   31.3           -        9252.0
# 2404          25.7      11.0       15.3   28.7           -       40633.0
#
#       student_staff_ratio international_students female_male_ratio  year  \
# 2003                 15.9                    15%           48 : 52  2016
# 2056                 24.2                    17%           32 : 68  2016
# 1908                 13.6                    14%           54 : 46  2016
# 2105                 19.2                    18%           48 : 52  2016
# 2404                 15.6                     1%           71 : 29  2016
#
#                         UNI_ID  females_p  males_p  females_num  males_num
# 2003         aalborguniversity       0.48     0.52       8363.0     9059.0
# 2056           aaltouniversity       0.32     0.68       5152.0    10947.0
# 1908          aarhusuniversity       0.54     0.46      12903.0    10992.0
# 2105     aberystwythuniversity       0.48     0.52       4441.0     4811.0
# 2404  adammickiewiczuniversity       0.71     0.29      28849.0    11784.0

# %%
pd.DataFrame(times_recent.groupby('country')['females_num'].sum()).head()
# Out:
#             females_num
# country
# Argentina       67191.0
# Australia      391736.0
# Austria         68364.0
# Bangladesh      21323.0
# Belarus         20219.0

# %%
pd.DataFrame(times_recent.groupby('country')['males_num'].sum()).head()
# Out:
#             males_num
# country
# Argentina     41182.0
# Australia    321640.0
# Austria       66113.0
# Bangladesh    41393.0
# Belarus        9084.0

# %% [markdown]
# ### 6.Find the universities where the ratio between female and male is below the average ratio (computed over all universities)

# %%
times_recent['gender_ratio'] = times_recent['females_num']/times_recent['males_num']
times_recent.tail()
# Out:
#      world_rank                           university_name      country  \
# 1856         54                  École Normale Supérieure       France
# 2013    201-250          École Normale Supérieure de Lyon       France
# 1904       =101                       École Polytechnique       France
# 1833         31  École Polytechnique Fédérale de Lausanne  Switzerland
# 2134    301-350                         Örebro University       Sweden
#
#       teaching international  research  citations income total_score  \
# 1856      70.6          85.5      47.7       87.1   37.1        69.0
# 2013      41.6          65.6      30.0       69.0   31.7           -
# 1904      53.5          92.8      44.6       64.7   82.3        57.9
# 1833      61.3          98.6      67.5       94.6   65.4        76.1
# 2134      18.3          39.4      10.4       87.8   29.8           -
#
#       num_students  student_staff_ratio international_students  \
# 1856        2400.0                  7.9                    20%
# 2013        2218.0                  8.0                    14%
# 1904        2429.0                  4.8                    30%
# 1833        9666.0                 10.5                    54%
# 2134        8788.0                 15.8                     2%
#
#      female_male_ratio  year                                UNI_ID  females_p  \
# 1856           46 : 54  2016                écolenormalesupérieure       0.46
# 2013           49 : 51  2016          écolenormalesupérieuredelyon       0.49
# 1904           18 : 82  2016                    écolepolytechnique       0.18
# 1833           27 : 73  2016  écolepolytechniquefédéraledelausanne       0.27
# 2134           61 : 39  2016                      örebrouniversity       0.61
#
#       males_p  females_num  males_num  gender_ratio
# 1856     0.54       1104.0     1296.0      0.851852
# 2013     0.51       1087.0     1131.0      0.961096
# 1904     0.82        437.0     1992.0      0.219378
# 1833     0.73       2610.0     7056.0      0.369898
# 2134     0.39       5361.0     3427.0      1.564342

# %%
times_recent.sort_values('females_p',ascending=False).head()
# Out:
#      world_rank                  university_name               country  \
# 2227    401-500           Ewha Womans University           South Korea
# 2388    501-600               Soochow University                 China
# 2413    601-800               Anadolu University                Turkey
# 2036    201-250         Royal Veterinary College        United Kingdom
# 2398    501-600  United Arab Emirates University  United Arab Emirates
#
#       teaching international  research  citations income total_score  \
# 2227      23.9          34.3      18.3       50.4   57.6           -
# 2388      19.2          16.0      13.7       45.8   75.3           -
# 2413      12.2          14.3      22.6       10.9  100.0           -
# 2036      26.0          81.7      27.8       74.9   45.5           -
# 2398      18.8          95.0      14.8       21.7   30.1           -
#
#       num_students  student_staff_ratio international_students  \
# 2227       17625.0                 14.4                     6%
# 2388       36465.0                 12.9                     2%
# 2413      379231.0                162.6                     1%
# 2036        1819.0                 10.9                    18%
# 2398        9221.0                 12.5                    26%
#
#      female_male_ratio  year                        UNI_ID  females_p  \
# 2227           100 : 0  2016          ewhawomansuniversity       1.00
# 2388           78 : 22  2016             soochowuniversity       0.78
# 2413           78 : 22  2016             anadoluuniversity       0.78
# 2036           77 : 23  2016        royalveterinarycollege       0.77
# 2398           76 : 24  2016  unitedarabemiratesuniversity       0.76
#
#       males_p  females_num  males_num  gender_ratio
# 2227     0.00      17625.0        0.0           inf
# 2388     0.22      28443.0     8022.0      3.545625
# 2413     0.22     295800.0    83431.0      3.545445
# 2036     0.23       1401.0      418.0      3.351675
# 2398     0.24       7008.0     2213.0      3.166742

# %%
times_recent['gender_ratio'].mean()
# there are some values of 'males' = 0
# Out:
# inf

# %%
# Considero nullo il valore infinito
times_recent['gender_ratio'].replace(np.Inf,np.nan, inplace=True)

# %%
media_ratio = times_recent['gender_ratio'].mean()

# %%
times_recent[times_recent['gender_ratio'] <= media_ratio]
# Out:
#      world_rank                                    university_name  \
# 2003    201-250                                 Aalborg University
# 2056    251-300                                   Aalto University
# 2105    301-350                             Aberystwyth University
# 2406    601-800                                    Ajou University
# 2408    601-800                              Alexandria University
# 2410    601-800                          Aligarh Muslim University
# 2303    501-600                      American University of Beirut
# 2411    601-800                     American University of Sharjah
# 2304    501-600                 Amirkabir University of Technology
# 2414    601-800                                  Andhra University
# 1991        189                           Arizona State University
# 2418    601-800        Athens University of Economics and Business
# 2307    501-600                                  Auburn University
# 2420    601-800                        Austral University of Chile
# 2310    501-600           Bauman Moscow State Technical University
# 2059    251-300                                Bayreuth University
# 2311    501-600                 Ben-Gurion University of the Negev
# 2154    351-400  Binghamton University, State University of New...
# 2424    601-800  Birla Institute of Technology and Science, Pilani
# 2313    501-600                                Boğaziçi University
# 2211    401-500                      Brno University of Technology
# 2212    401-500                           Brunel University London
# 2429    601-800    Budapest University of Technology and Economics
# 2430    601-800                                   Cairo University
# 1803          1                 California Institute of Technology
# 2316    501-600                                Carleton University
# 2438    601-800                    Carlos III University of Madrid
# 1824         22                         Carnegie Mellon University
# 1936       =133                    Case Western Reserve University
# 2008    201-250                  Chalmers University of Technology
# ...         ...                                                ...
# 2397    501-600                                University of Tulsa
# 1954       =149                               University of Twente
# 1986       =182                                 University of Utah
# 2589    601-800                                 University of Vigo
# 1882         80                              University of Warwick
# 1981        179                             University of Waterloo
# 1912        109                    University of Western Australia
# 1852         50                    University of Wisconsin-Madison
# 2103    251-300                           University of Wollongong
# 2587    601-800                            Ural Federal University
# 2101    251-300                    Vienna University of Technology
# 2102    251-300  Virginia Polytechnic Institute and State Unive...
# 2150    301-350              VŠB - Technical University of Ostrava
# 2052    201-250                             Wake Forest University
# 2591    601-800                    Warsaw University of Technology
# 2592    601-800                                  Waseda University
# 2202    351-400                        Washington State University
# 1802    351-400                     Wuhan University of Technology
# 2597    601-800                                  Xidian University
# 2401    501-600                          Xi’an Jiaotong University
# 1814         12                                    Yale University
# 2598    601-800                                Yeungnam University
# 2601    601-800                       Yokohama National University
# 2602    601-800                                 Yuan Ze University
# 2599    601-800                        Yıldız Technical University
# 2104    251-300                                Zhejiang University
# 1856         54                           École Normale Supérieure
# 2013    201-250                   École Normale Supérieure de Lyon
# 1904       =101                                École Polytechnique
# 1833         31           École Polytechnique Fédérale de Lausanne
#
#                        country  teaching international  research  citations  \
# 2003                   Denmark      25.1          71.0      28.4       73.8
# 2056                   Finland      31.1          65.4      32.8       62.1
# 2105            United Kingdom      21.6          72.2      18.9       67.2
# 2406               South Korea      19.5          20.0      11.9       23.9
# 2408                     Egypt      20.3          33.7       8.2       14.1
# 2410                     India      28.3          18.7      10.0       20.9
# 1986      11553.0    14121.0      0.818143
# 2589      11624.0    11169.0      1.040738
# 1882       8894.0     9635.0      0.923093
# 1981      13827.0    16899.0      0.818214
# 1912      10426.0    10426.0      1.000000
# 1852      20224.0    19431.0      1.040811
# 2103       8244.0     8244.0      1.000000
# 2587      13645.0    14782.0      0.923082
# 2101       7133.0    19286.0      0.369854
# 2102      12957.0    17893.0      0.724138
# 2150       7346.0     7645.0      0.960889
# 2052       3736.0     3590.0      1.040669
# 2591      11754.0    22818.0      0.515120
# 2592      18311.0    34005.0      0.538480
# 2202      12275.0    12275.0      1.000000
# 1802      15581.0    34679.0      0.449292
# 2597       9169.0    22449.0      0.408437
# 2401      10153.0    19710.0      0.515119
# 1814       5876.0     5876.0      1.000000
# 2598      10540.0    11418.0      0.923104
# 2601       2833.0     7284.0      0.388935
# 2602       3725.0     4938.0      0.754354
# 2599      11256.0    20012.0      0.562463
# 2104      19478.0    28030.0      0.694898
# 1856       1104.0     1296.0      0.851852
# 2013       1087.0     1131.0      0.961096
# 1904        437.0     1992.0      0.219378
# 1833       2610.0     7056.0      0.369898
#
# [346 rows x 20 columns]

# %% [markdown]
# ### 7.For each country compute the fraction of students that are in one of the universities computed in the previous point.

# %%
# Create dataset resultin from point 6
uni_below = times_recent[times_recent['gender_ratio'] <= media_ratio]

# %%
students_below = pd.DataFrame(uni_below.groupby('country')['num_students'].sum())
students_below.head()
# Out:
#             num_students
# country
# Australia       146235.0
# Austria          61033.0
# Bangladesh       62716.0
# Brazil          278774.0
# Canada           86779.0

# %%
# Tot studenti per country
students_per_country = pd.DataFrame(times_recent.groupby('country')['num_students'].sum())
students_per_country.head()
# Out:
#             num_students
# country
# Argentina       108373.0
# Australia       743627.0
# Austria         134477.0
# Bangladesh       62716.0
# Belarus          29303.0

# %%
union = pd.merge(students_below,students_per_country,
                on = 'country',suffixes=('_below', '_tot'),how='outer')

# I valori nulli corrispondono ai paesi che non hanno studenti nelle università 
# identificate al punto 6

union['num_students_below'].replace(np.nan,0,inplace=True)

union.head()
# Out:
#             num_students_below  num_students_tot
# country
# Australia             146235.0          743627.0
# Austria                61033.0          134477.0
# Bangladesh             62716.0           62716.0
# Brazil                278774.0          534688.0
# Canada                 86779.0          717054.0

# %%
union['fraction'] = union['num_students_below']/union['num_students_tot']
union
# Out:
#                           num_students_below  num_students_tot  fraction
# country
# Australia                           146235.0          743627.0  0.196651
# Austria                              61033.0          134477.0  0.453855
# Bangladesh                           62716.0           62716.0  1.000000
# Brazil                              278774.0          534688.0  0.521377
# Canada                               86779.0          717054.0  0.121022
# Chile                                90951.0          116026.0  0.783885
# China                               885293.0         1285619.0  0.688612
# Colombia                             54645.0           54645.0  1.000000
# Czech Republic                       38685.0          203321.0  0.190266
# Denmark                              45705.0          119355.0  0.382933
# Egypt                               359372.0          376189.0  0.955296
# Estonia                              14061.0           24330.0  0.577928
# Finland                              39788.0          106165.0  0.374775
# France                              156153.0          694221.0  0.224933
# Germany                             435244.0          948489.0  0.458881
# Ghana                                37274.0           37274.0  1.000000
# Greece                               57198.0          202013.0  0.283140
# Hong Kong                            32079.0           91656.0  0.349993
# Hungary                              22447.0          138282.0  0.162328
# India                               155370.0          191154.0  0.812800
# Indonesia                            43565.0           43565.0  1.000000
# Iran                                107280.0          138992.0  0.771843
# Israel                               30550.0          107400.0  0.284451
# Italy                               106471.0         1243124.0  0.085648
# Japan                               447415.0          563422.0  0.794103
# Kenya                                72676.0           72676.0  1.000000
# Lebanon                               7695.0            7695.0  1.000000
# Luxembourg                            5144.0            5144.0  1.000000
# Malaysia                             16270.0          161827.0  0.100539
# Mexico                              151731.0          151731.0  1.000000
# ...                                      ...               ...       ...
# Russian Federation                  119356.0          214008.0  0.557717
# Singapore                            56620.0           56620.0  1.000000
# Slovakia                             16400.0           37279.0  0.439926
# South Korea                         276058.0          442372.0  0.624040
# Spain                               136088.0          830331.0  0.163896
# Sweden                               20667.0          187293.0  0.110346
# Switzerland                          34692.0          130940.0  0.264946
# Taiwan                              209949.0          308940.0  0.679579
# Thailand                             66058.0          210122.0  0.314379
# Turkey                              216017.0          639342.0  0.337874
# Uganda                               37340.0           37340.0  1.000000
# Ukraine                              22686.0           37096.0  0.611548
# United Arab Emirates                  5226.0           14447.0  0.361736
# United Kingdom                      259977.0         1324842.0  0.196232
# United States of America           1726340.0         3280303.0  0.526275
# Argentina                                0.0          108373.0  0.000000
# Belarus                                  0.0           29303.0  0.000000
# Belgium                                  0.0          169661.0  0.000000
# Cyprus                                   0.0            6880.0  0.000000
# Iceland                                  0.0           13960.0  0.000000
# Jordan                                   0.0           60263.0  0.000000
# Latvia                                   0.0           15100.0  0.000000
# Lithuania                                0.0           19019.0  0.000000
# Macau                                    0.0            8521.0  0.000000
# Qatar                                    0.0            9583.0  0.000000
# Romania                                  0.0          108378.0  0.000000
# Saudi Arabia                             0.0           83453.0  0.000000
# Serbia                                   0.0           96968.0  0.000000
# Slovenia                                 0.0           63352.0  0.000000
# South Africa                             0.0          330198.0  0.000000
#
# [70 rows x 3 columns]

# %% [markdown]
# ### 8.Read the file educational_attainment_supplementary_data.csv, discarding any row without country_name or series_name

# %%
# importing the dataset 

url = 'https://drive.google.com/file/d/1VFpCwild-pdSp6I5e7La1ytNWKAaJVGt/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
ed_a_s = pd.read_csv(path)

# %%
ed_a_s.head()
# Out:
#   country_name                                        series_name  1985  1986  \
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33   NaN
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03   NaN
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83   NaN
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34   NaN
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54   NaN
#
#    1987  1990  1991  1992  1993  1995  ...  2005  2006  2007  2008  2009  \
# 0   NaN  0.44   NaN   NaN   NaN  0.57  ...  0.86   NaN   NaN   NaN   NaN
# 1   NaN  1.26   NaN   NaN   NaN  1.54  ...  2.18   NaN   NaN   NaN   NaN
# 2   NaN  0.95   NaN   NaN   NaN  1.26  ...  1.01   NaN   NaN   NaN   NaN
# 3   NaN  2.22   NaN   NaN   NaN  2.37  ...  2.26   NaN   NaN   NaN   NaN
# 4   NaN  0.92   NaN   NaN   NaN  0.94  ...  2.00   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2015
# 0  1.27   NaN   NaN   NaN   NaN
# 1  2.64   NaN   NaN   NaN   NaN
# 2  2.45   NaN   NaN   NaN   NaN
# 3  3.55   NaN   NaN   NaN   NaN
# 4  1.29   NaN   NaN   NaN   NaN
#
# [5 rows x 29 columns]

# %%
ed_a_s.dropna(subset=['country_name', 'series_name'], inplace=True)

# %%
# check
ed_a_s['country_name'].isnull().sum()
# Out:
# 0

# %%
# check
ed_a_s['series_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 9.From attainment build a dataframe with the same data, but with 4 columns: country_name, series_name, year, value

# %%
ed_a_s = pd.melt(frame = ed_a_s, id_vars= ['country_name','series_name'], var_name = 'year', value_name='value')

# %%
ed_a_s.head()
# Out:
#   country_name                                        series_name  year  value
# 0  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.33
# 1  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   1.03
# 2  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.83
# 3  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   2.34
# 4  Afghanistan  Barro-Lee: Average years of primary schooling,...  1985   0.54

# %% [markdown]
# ### 10.For each university, find the number of rankings in which they appear (it suffices to appear in one year for each ranking).

# %%
shanghai_uni = list(shanghai['UNI_ID'].unique())
times_uni = list(times['UNI_ID'].unique())
cwur_uni = list(cwur['UNI_ID'].unique())

# %%
# Funzione conta il numero apparizioni nelle tre liste

def get_appearances(uni):
    count=0
    if uni in shanghai_uni:
        count+=1
    if uni in times_uni:
        count+=1
    if uni in cwur_uni:
        count+=1
        
    return count

# %%
prova = 'harvarduniversity'
get_appearances(prova)
# Out:
# 3

# %%
schools_countries['n_appearances']=schools_countries['UNI_ID'].apply(get_appearances)

# %%
schools_countries.head()
# Out:
#                          university_name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#                              UNI_ID  n_appearances
# 0                 harvarduniversity              3
# 1     californiainstitutetechnology              3
# 2  massachusettsinstitutetechnology              2
# 3                stanforduniversity              3
# 4               princetonuniversity              3

# %% [markdown]
# ### 11.In the times ranking, compute the number of times each university appears

# %%
times_app = pd.DataFrame(times.groupby('UNI_ID').size(),columns=['n_times'])
times_app.head()
# Out:
#                           n_times
# UNI_ID
# aalborguniversity               5
# aaltouniversity                 5
# aarhusuniversity                6
# aberystwythuniversity           5
# adammickiewiczuniversity        1

# %%
# Referencing to school_countries to get standard names

uni_names_app = pd.merge(times_app,schools_countries,on='UNI_ID')
uni_names_app=uni_names_app[['university_name','n_times']]
uni_names_app.head()
# Out:
#               university_name  n_times
# 0          Aalborg University        5
# 1            Aalto University        5
# 2           Aarhus University        6
# 3      Aberystwyth University        5
# 4  Adam Mickiewicz University        1

# %% [markdown]
# ### 12.Find the universities that appear at most twice in the times ranking.

# %%
uni_names_app[uni_names_app['n_times']<=2].head()
# Out:
#                             university_name  n_times
# 4                Adam Mickiewicz University        1
# 5  AGH University of Science and Technology        1
# 6                  Aix-Marseille University        1
# 7                           Ajou University        1
# 9            Alexandru Ioan Cuza University        1

# %% [markdown]
# ### 13.The universities that, in any year, have the same position in all three rankings (they must have the same position in a year).

# %%
shanghai.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year  \
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005
#
#                                   UNI_ID
# 0                      harvarduniversity
# 1                    universitycambridge
# 2                     stanforduniversity
# 3           universitycaliforniaberkeley
# 4  massachusettsinstitutetechnology(mit)

# %%
times_slim=times[['UNI_ID','year','world_rank']]
shanghai_slim=shanghai[['UNI_ID','year','world_rank']]
cwur_slim=cwur[['UNI_ID','year','world_rank']]

# %%
# Unione dei tre dataset

shanghai_slim.rename(columns = {'world_rank':'world_rank_shanghai'},inplace=True)


merged_full=pd.merge(pd.merge(cwur_slim,times_slim,on=['UNI_ID','year'],suffixes=('_cwur', '_times')),
                shanghai_slim,
                on=['UNI_ID','year'])

merged_full.head()
# Out:
#                           UNI_ID  year  world_rank_cwur world_rank_times  \
# 0              harvarduniversity  2012                1                2
# 1             stanforduniversity  2012                3                2
# 2            universitycambridge  2012                4                6
# 3  californiainstitutetechnology  2012                5                1
# 4            princetonuniversity  2012                6                5
#
#   world_rank_shanghai
# 0                   1
# 1                   2
# 2                   5
# 3                   6
# 4                   7

# %%
# Recall function developped at point 4
merged_full['world_rank_shanghai_num']=merged_full['world_rank_shanghai'].apply(get_mean_range)
merged_full['world_rank_times_num']=merged_full['world_rank_times'].apply(get_mean_range)

# %%
# Funzione che verifica l'uguaglianza tra rankings

def find_same_rank(row):
    if float(row['world_rank_cwur'])==row['world_rank_shanghai_num']==row['world_rank_times_num']:
        return True
    else:
        return False

# %%
merged_full['same_rank'] = merged_full.apply(find_same_rank, axis=1)

# %%
merged_full[merged_full['same_rank']]
# Out:
#                 UNI_ID  year  world_rank_cwur world_rank_times  \
# 61  stanforduniversity  2013                2                2
#
#    world_rank_shanghai  world_rank_shanghai_num  world_rank_times_num  \
# 61                   2                      2.0                   2.0
#
#     same_rank
# 61       True

# %% [markdown]
# #### 13. Soluzione alternativa

# %%
merged_full['world_rank_shanghai']=merged_full['world_rank_shanghai'].str.strip('=')
merged_full['world_rank_shanghai_list']=merged_full['world_rank_shanghai'].str.split('-')

merged_full['world_rank_times']=merged_full['world_rank_times'].str.strip('=')
merged_full['world_rank_times_list']=merged_full['world_rank_times'].str.split('-')

merged_full.head()
# Out:
#                           UNI_ID  year  world_rank_cwur world_rank_times  \
# 0              harvarduniversity  2012                1                2
# 1             stanforduniversity  2012                3                2
# 2            universitycambridge  2012                4                6
# 3  californiainstitutetechnology  2012                5                1
# 4            princetonuniversity  2012                6                5
#
#   world_rank_shanghai  world_rank_shanghai_num  world_rank_times_num  \
# 0                   1                      1.0                   2.0
# 1                   2                      2.0                   2.0
# 2                   5                      5.0                   6.0
# 3                   6                      6.0                   1.0
# 4                   7                      7.0                   5.0
#
#    same_rank world_rank_shanghai_list world_rank_times_list
# 0      False                      [1]                   [2]
# 1      False                      [2]                   [2]
# 2      False                      [5]                   [6]
# 3      False                      [6]                   [1]
# 4      False                      [7]                   [5]

# %%
def rank_compare(row):
    
    cwur=row['world_rank_cwur']
    shanghai=row['world_rank_shanghai_list']
    times=row['world_rank_times_list']
    
    
    if len(shanghai)==2 and len(times)==2:
        
        if(
        int(shanghai[0]) <= cwur <= int(shanghai[1]) and 
        int(times[0]) <= cwur <= int(times[1])
        ):
            
            return True
        else:
        
            return False 
    
    
    if len(shanghai)==1 and len(times)==2:
        
        if( 
        int(shanghai[0])==cwur and 
        int(times[0]) <= cwur <= int(times[1])
        ):
                
            return True
        else:
        
            return False 
    
            
    if len(times)==1 and len(shanghai)==2:
        
        if(        
        int(times[0])==cwur and             
        int(shanghai[0]) <= cwur <= int(shanghai[1])
        ):
                
            return True
        else:
        
            return False 
    
    
    if len(times)==1 and len(shanghai)==1:
    
        if int(times[0])==cwur and int(shanghai[0])==cwur:
        
            return True
        else:
        
            return False

# %%
merged_full['rank_compare']=merged_full.apply(rank_compare ,axis=1)

# %%
merged_full[merged_full['rank_compare']]
# Out:
#                             UNI_ID  year  world_rank_cwur world_rank_times  \
# 61              stanforduniversity  2013                2                2
# 196          universitysouthampton  2014              146              146
# 277              universityvermont  2014              320          301-350
# 297               templeuniversity  2014              390          351-400
# 465            newcastleuniversity  2015              212          201-225
# 474                lavaluniversity  2015              229          226-250
# 480  autonomousuniversitybarcelona  2015              241          226-250
# 492        medicaluniversityvienna  2015              265          251-275
# 493             universitywaterloo  2015              269          251-275
# 534                universityturku  2015              383          351-400
#
#     world_rank_shanghai  world_rank_shanghai_num  world_rank_times_num  \
# 61                    2                      2.0                   2.0
# 196             101-150                    125.5                 146.0
# 277             301-400                    350.5                 325.5
# 297             301-400                    350.5                 375.5
# 465             201-300                    250.5                 213.0
# 474             201-300                    250.5                 238.0
# 480             201-300                    250.5                 238.0
# 492             201-300                    250.5                 263.0
# 493             201-300                    250.5                 263.0
# 534             301-400                    350.5                 375.5
#
#      same_rank world_rank_shanghai_list world_rank_times_list  rank_compare
# 61        True                      [2]                   [2]          True
# 196      False               [101, 150]                 [146]          True
# 277      False               [301, 400]            [301, 350]          True
# 297      False               [301, 400]            [351, 400]          True
# 465      False               [201, 300]            [201, 225]          True
# 474      False               [201, 300]            [226, 250]          True
# 480      False               [201, 300]            [226, 250]          True
# 492      False               [201, 300]            [251, 275]          True
# 493      False               [201, 300]            [251, 275]          True
# 534      False               [301, 400]            [351, 400]          True
